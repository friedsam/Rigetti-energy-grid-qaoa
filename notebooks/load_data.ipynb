# %%
from pathlib import Path
import pandas as pd
import networkx as nx

# Find project root (one level above notebooks)
PROJECT_ROOT = Path.cwd().parent
DATA_PATH = PROJECT_ROOT / "data"

print("Notebook cwd:", Path.cwd())
print("Project root:", PROJECT_ROOT)
print("Data folder exists:", DATA_PATH.exists())
print("Files in data:", list(DATA_PATH.iterdir()))

# Adjust filename here if needed
parquet_file = DATA_PATH / "problem_a.parquet"

df = pd.read_parquet(parquet_file)

G = nx.Graph()
for u, v, w in df[["node_1", "node_2", "weight"]].itertuples(index=False):
    G.add_edge(int(u), int(v), weight=float(w))

print("Nodes:", G.number_of_nodes())
print("Edges:", G.number_of_edges())
print("Done.")

weights = [d["weight"] for _,_,d in G.edges(data=True)]
print("Weight min/mean/max:", min(weights), sum(weights)/len(weights), max(weights))
# Out:
# Notebook cwd: /Users/claudia/Documents/Documents - Claudia’s MacBook Pro/Workspace/Quantum Computing/Q-volution/Rigetti/energy-grid-qaoa/notebooks
# Project root: /Users/claudia/Documents/Documents - Claudia’s MacBook Pro/Workspace/Quantum Computing/Q-volution/Rigetti/energy-grid-qaoa
# Data folder exists: True
# Files in data: [PosixPath('/Users/claudia/Documents/Documents - Claudia’s MacBook Pro/Workspace/Quantum Computing/Q-volution/Rigetti/energy-grid-qaoa/data/problem_b.parquet'), PosixPath('/Users/claudia/Documents/Documents - Claudia’s MacBook Pro/Workspace/Quantum Computing/Q-volution/Rigetti/energy-grid-qaoa/data/problem_a.parquet'), PosixPath('/Users/claudia/Documents/Documents - Claudia’s MacBook Pro/Workspace/Quantum Computing/Q-volution/Rigetti/energy-grid-qaoa/data/.gitkeep')]
# Nodes: 21
# Edges: 28
# Done.
# Weight min/mean/max: 40.841596159559 150.5594813948614 382.718543464903
